# %% [markdown]
# <a href="https://colab.research.google.com/github/HCelante/Compilador/blob/Lexica/Execu%C3%A7%C3%A3o_dos_Testes_da_L%C3%A9xica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Execução dos Testes da Análise Léxica
#
# 1. Faça uma cópia desse script do Colab para seu Google Drive, vá em _Arquivo_ e depois em _Salvar Cópia no Drive_.
#
# 2. Execute as células na sequência e enviei ao final o __Relatório de Execução dos Testes__ que será gerado pelo _script_ `run-testes.sh`.

# %% [markdown]
# # Instalação do `PLY`

# %%
# !pip install ply
# Out:
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 2.7 MB/s
# Installing collected packages: ply
# Successfully installed ply-3.11

# %% [markdown]
# # Faça _upload_ do arquivo `lexica-testes.zip`

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-738b58db-530a-4451-9609-2316c7cd3216" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-738b58db-530a-4451-9609-2316c7cd3216">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lexica-testes.zip to lexica-testes (1).zip
# {'lexica-testes.zip': b'PK\x03\x04\x14\x03\x00\x00\x00\x00\xdc\xa8\nS\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0e\x00\x00\x00lexica-testes/PK\x03\x04\x14\x03\x00\x00\x08\x00\xb5\x81\x9eQE\x99\xdb\xca\xa9\x00\x00\x00m\x01\x00\x00&\x00\x00\x00lexica-testes/Busca_Linear_1061992.tpp\x85\x90A\n\xc20\x10E\xd7)\xf4\x0e\xb3\x8c\xb8\x89]\x16\xba\xf0\x1c\xd2\xc5X"\x0c\xd44$\xd1;y\x0e/\xe6L\x1aB\x10D\xc8b\xf2>\x9f\xffg\xfa\x8e\\\xb2\x14\xb6\x11\xce\x97\xc1\xcc}W\t\\\x1fqA]uw\xe8;\xc5\xaf\x82`\xd3\x16\xdc\xd6"\x12\xbf*\x02\x8c\x13\x18Q\xf3P\x14O\t\x81\'\x15-\'\xd2\x0c\x138\xf9\xb6\xa6\x93\x80\x1b\xdd\x95\xc4\xedv\x82c\xc6\x98\xde/ 6\r\xa6\x89B]\xdc\\\x91}\xed\x12>\x90[\xc8\xe3\xaaY\xfb\xaa\xfa\xb3\x9b\x14\xcb\xa9\x7f\xf3WK\xa8\xf3el\\\x82}\xa2\x96\xab\t\x12VZi\xb3\xf7\xfa\x00PK\x03\x04\x14\x03\x00\x00\x08\x00j\x8djR\x8f\x89\x83b\xa1\x00\x00\x00\x13\x03\x00\x00*\x00\x00\x00lexica-testes/Busca_Linear_1061992.tpp.out\xa5\x90[\x0e\xc4 \x08E\xff\xdd\x15U:%Q1\xa8\xf3\xeb\xfew1\x0f\xe7\x11\xa3\xadM\xfa\t\xdc\x0b\xdcC>!\t+\xc3\x14K`\x9f8*2\n\x16\xc1\xa2\xd9\xea\r\x13*\x9f]\xf9\nW\xd4\x1b\xfcG\x9f\xf6\xcf\x13@\xf0\xd9\x8a\xa8\xc6\x9b\xab\x7f.\x1b\xb7\xdfg\x92\xd0\x92I\x037\x7f\xedO\x04\x03%P\x11\xfb`d\xba<\xb7\x0c\xf6\xf8\xd2J\xae\x9d\xbe*\x07\x14\x1b\x15\xd4\xf5u_\xfbNb\xf1\xd0\xe1\xea\xd0\xd4C{|O\x82\x9cs\x99Ci\xa3^\xc9n\x91\xce\x04\xc7\xa8\x05\xef\x03\xe5\xdc[\xeb#S\xf3\xd0\x08\xf9\x03PK\x03\x04\x14\x03\x00\x00\x08\x00S\xa3YR\x04I7\x00\xd0\x00\x00\x00\r\x02\x00\x00$\x00\x00\x00lexica-testes/bubble_sort-2020-2.tppeQA\n\x830\x10\xbc\xe7\x15{TD\x88\x1e\x05\x0b}C\x8f\xc5C,\x116\xd8(i\x02\xfdOO}\x87\x1fk\xba)\xa1\xab\xb9\xb8;3\xcel6\xd3\x1c|P\xd6\xeb\x0e\xce\xd7V\x0eB\x8ca\x1cg}Y\x9c/0\xe2\xe8\x96\x0el) \x9e\xdc#o\r\xb5\t\x83\xae\x07I\xa5I%\xd5N\xaf\xe8\x15\x95\xbc\xcd\xe7\xa1\xe3\x00f\x80\xd3\xf7S5\x03h\xeb\xb7\xd7\xc24,T\x85\xa78\xb0\x11\x8c\xa9\xe4\xb4\xe7\x08$\x92\xfc\x0f4\xc1$\x88&\x8c\x9d\xf0\xce\x93\xe8f\x06*h2\xac\xfc\xf6\x8eP\x0f\x85\xad\xb1n\xca\xf4C\xde\x08\x928\x0b1\n\xad _\xf1\xbb\x10\xac\x0e\xed\rW5\x17\x87eg\x9bV\xb2m\xe6\xc9\x11jH\xb3\xe3>\xb7\xe6\xb9\xf9E\xfe\x9e\xb9\x95e\x9a\xe5\x03PK\x03\x04\x14\x03\x00\x00\x08\x00j\x8djR=\xb6S\xba\xb9\x00\x00\x00\xf6\x03\x00\x00(\x00\x00\x00lexica-testes/bubble_sort-2020-2.tpp.out\x95RI\x0e\xc3 \x0c\xbc\xf3+\x878\x8d\xa5\x80\x11\xcb\x99\xff\xff\xa2\x88(\xb4\x82\xb2\xf4\x94\x88\x19{\x16\xf9\xb8\x82\x0f\xa0=\x8a\x9d\xc9E\xc3\xda\xb3\x13\xb4\x0b\xd8,F\xc9\x97<1\x81:\xa8H\x89E\x96\xc5\x81\xf2\x84\x02\x15\xae\x01\x8b\x89\xe1P<\xc4jc\x9e\x9b\xd2:\xcfY\xc6[\xda\x02I\xe0o?\x03\xc4\xa2!\x0f\xcf\xc7a\x9b\x8b\xf6:\x8e\x02b\xfb\x93\x98\x107*"\xc5\x02^\xb3?\xf7\xb1@\x19.\x9c\xfb]\x9a\x19K\x1e\xa4\x9a`\xed\n\xb8W\xd3+\xc0U\x9dJ\xe6\xa3fW~Z\xf1\x0f\xfbO\xad\xe2\xf0\xc6\xdaC]\xbc\xc8\xe9\x81\xd5M\x96X\x8bU6\x1ae\xbe\x9b-\x03\xdd`\xa3\x12s%oPK\x03\x04\x14\x03\x00\x00\x08\x00\xb5\x81\x9eQ\xd8n\x92\xb9\x0b\x01\x00\x00o\x02\x00\x00\x1d\x00\x00\x00lexica-testes/bubble_sort.tppuQKN\xc30\x14\xdc\xfb\x14\xb3l\x85\x90\x92mE9\x06\x9b*BN0\xf0\xac\xf8#\xc7t\x838\r\x0b\xc49r1\x9e\x8d\xdd\xa6\xa9\xbaI\xde\xbc\x19O&c\xb2QQp;\x1cU<\xb4M\'N\x8b(\x8d\x10\xfc\xc0n\x8f\xb6\x11\xe2\x13>(e\x87w\x05\x97\xd4.\xc0:x\xe2\xf7 \'\x87/Q\xf9\xa7Dn\xb6\x028\x99\xd1\x12\xe8\x04\x92m\xc3\x83\xe6!\x7f\x0b\x08\xcaS\x94< \xa7\xa1\x0e\xfb\xac-j\xc2\x1dZ\x86\xe5\x8c\xc6}\x862\xce\xbf\xcc=d\x93W2))\x19?*\xa3l\x94\xf3\xcf\xfc\xed\xf0\xe2\xd0\x7f\xf4\xfd\xa80\xb9\x109\xea?zNh\x1d\xb4f[\x06Z\x85\x07t\x95\\\x88\x80I\xd5\xe8\x8f8\x1et\x07\xce\xc0\x01\n\xbb\xb0\x89\xca\xf8\xba\xcd\x80\r\xcb\xd1\xba.\xb0\x12\xfa\x92\xd0\x89X\xda\xa4_\x07\xce\xf5\x94\xb6JA\x9a\x0b\xa2U\x977\xca\xf3\xc1\xbd\x05i$\x0fd\x07\xf2r\xe4\xc2J\xf0\xf3.\xd7v}\xe3\xebbCb\xac\xdc4\xdbl\xff\x07PK\x03\x04\x14\x03\x00\x00\x08\x00j\x8djRp\xda\n\xfd\xb1\x00\x00\x00:\x04\x00\x00!\x00\x00\x00lexica-testes/bubble_sort.tpp.out\xb5SK\x12\x83 \x0c\xdds\xab\x88i\xcd\x8c\x10\'\xc4\xb5\xf7\xbfE\x19\x1c?\x95\xb6\xa0S\x97!\xef\x93G\x80\xbc"\t\x9b\x96)L\x03{\xe5`\xa85\xd0\x08N\x96{\xdb\xa1\xa2\x ...

# %% [markdown]
# # Faça _upload_ do arquivo do Analisar

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8abd24c4-d6bb-472c-b28b-bc913bc8e101" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8abd24c4-d6bb-472c-b28b-bc913bc8e101">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lexeHigor.py to lexeHigor (7).py
# {'lexeHigor.py': b'from ply.lex import TOKEN\r\nimport ply.lex as lex\r\nfrom sys import argv, exit\r\n\r\nimport logging\r\nlogging.basicConfig(\r\n    level=logging.DEBUG,\r\n    filename="log.txt",\r\n    filemode="w",\r\n    format="%(filename)10s:%(lineno)4d:%(message)s"\r\n)\r\nlog = logging.getLogger()\r\n\r\n\r\ntokens = [\r\n    "ID",  # identificador\r\n    # numerais\r\n    "NUM_NOTACAO_CIENTIFICA",  # ponto flutuante em nota\xc3\xa7ao cient\xc3\xadfica\r\n    "NUM_PONTO_FLUTUANTE",  # ponto flutuate\r\n    "NUM_INTEIRO",  # inteiro\r\n    # operadores binarios\r\n    "MAIS",  # +\r\n    "MENOS",  # -\r\n    "MULTIPLICACAO",  # *\r\n    "DIVISAO",  # /\r\n    "E_LOGICO",  # &&\r\n    "OU_LOGICO",  # ||\r\n    "DIFERENCA",  # <>\r\n    "MENOR_IGUAL",  # <=\r\n    "MAIOR_IGUAL",  # >=\r\n    "MENOR",  # <\r\n    "MAIOR",  # >\r\n    "IGUAL",  # =\r\n    # operadores unarios\r\n    "NEGACAO",  # !\r\n    # simbolos\r\n    "ABRE_PARENTESE",  # (\r\n    "FECHA_PARENTESE",  # )\r\n    "ABRE_COLCHETE",  # [\r\n    "FECHA_COLCHETE",  # ]\r\n    "VIRGULA",  # ,\r\n    "DOIS_PONTOS",  # :\r\n    "ATRIBUICAO",  # :=\r\n    # \'COMENTARIO\', # {***}\r\n]\r\n\r\nreserved_words = {\r\n    "se": "SE",\r\n    "ent\xc3\xa3o": "ENTAO",\r\n    "sen\xc3\xa3o": "SENAO",\r\n    "fim": "FIM",\r\n    "repita": "REPITA",\r\n    "flutuante": "FLUTUANTE",\r\n    "retorna": "RETORNA",\r\n    "at\xc3\xa9": "ATE",\r\n    "leia": "LEIA",\r\n    "escreva": "ESCREVA",\r\n    "inteiro": "INTEIRO",\r\n}\r\n\r\ntokens = tokens + list(reserved_words.values())\r\n\r\ndigito = r"([0-9])"\r\nletra = r"([a-zA-Z\xc3\xa1\xc3\x81\xc3\xa3\xc3\x83\xc3\xa0\xc3\x80\xc3\xa9\xc3\x89\xc3\xad\xc3\x8d\xc3\xb3\xc3\x93\xc3\xb5\xc3\x95])"\r\nsinal = r"([\\-\\+]?)"\r\n\r\nid = (\r\n    r"(" + letra + r"(" + digito + r"+|_|" + letra + r")*)"\r\n)\r\ninteiro = r"\\d+"\r\n\r\nflutuante = (\r\n    r\'\\d+[eE][-+]?\\d+|(\\.\\d+|\\d+\\.\\d*)([eE][-+]?\\d+)?\'\r\n)\r\n\r\nnotacao_cientifica = (\r\n    r"(" + sinal + r"([1-9])\\." + digito + r"+[eE]" + sinal + digito + r"+)"\r\n)  \r\n\r\n# Express\xc3\xb5es Regulaes para tokens simples.\r\n# S\xc3\xadmbolos.\r\nt_MAIS = r\'\\+\'\r\nt_MENOS = r\'-\'\r\nt_MULTIPLICACAO = r\'\\*\'\r\nt_DIVISAO = r\'/\'\r\nt_ABRE_PARENTESE = r\'\\(\'\r\nt_FECHA_PARENTESE = r\'\\)\'\r\nt_ABRE_COLCHETE = r\'\\[\'\r\nt_FECHA_COLCHETE = r\'\\]\'\r\nt_VIRGULA = r\',\'\r\nt_ATRIBUICAO = r\':=\'\r\nt_DOIS_PONTOS = r\':\'\r\n\r\n# Operadores L\xc3\xb3gicos.\r\nt_E_LOGICO = r\'&&\'\r\nt_OU_LOGICO = r\'\\|\\|\'\r\nt_NEGACAO = r\'!\'\r\n\r\n# Operadores Relacionais.\r\nt_DIFERENCA = r\'<>\'\r\nt_MENOR_IGUAL = r\'<=\'\r\nt_MAIOR_IGUAL = r\'>=\'\r\nt_MENOR = r\'<\'\r\nt_MAIOR = r\'>\'\r\nt_IGUAL = r\'=\'\r\n\r\n\r\n@TOKEN(id)\r\ndef t_ID(token):\r\n    token.type = reserved_words.get(\r\n        token.value, "ID"\r\n    )  # n\xc3\xa3o \xc3\xa9 necess\xc3\xa1rio fazer regras/regex para cada palavra reservada\r\n    # se o token n\xc3\xa3o for uma palavra reservada automaticamente \xc3\xa9 um id\r\n    # As palavras reservadas t\xc3\xaam preced\xc3\xaancias sobre os ids\r\n\r\n    return token\r\n\r\n\r\n@TOKEN(notacao_cientifica)\r\ndef t_NUM_NOTACAO_CIENTIFICA(token):\r\n    return token\r\n\r\n\r\n@TOKEN(flutuante)\r\ndef t_NUM_PONTO_FLUTUANTE(token):\r\n    return token\r\n\r\n\r\n@TOKEN(inteiro)\r\ndef t_NUM_INTEIRO(token):\r\n    return token\r\n\r\n\r\nt_ignore = " \\t"\r\n\r\ndef t_COMENTARIO(token):\r\n    r"(\\{((.|\\n)*?)\\})"\r\n    token.lexer.lineno += token.value.count("\\n")\r\n    # return token\r\n\r\n\r\ndef t_newline(token):\r\n    r"\\n+"\r\n    token.lexer.lineno += len(token.value)\r\n\r\n\r\ndef define_column(input, lexpos):\r\n    begin_line = input.rfind("\\n", 0, lexpos) + 1\r\n    return (lexpos - begin_line) + 1\r\n\r\n\r\ndef t_error(token):\r\n\r\n    # file = token.lexer.filename\r\n    line = token.lineno\r\n    # column = define_column(token.lexer.backup_data, token.lexpos)\r\n    message = "Caracter inv\xc3\xa1lido \'%s\'" % tok ...

# %% [markdown]
# # Descompacte o arquivo com os testes

# %%
# !unzip lexica-testes.zip
# Out:
# Archive:  lexica-testes.zip
# replace lexica-testes/Busca_Linear_1061992.tpp? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # Copiando os arquivos de teste para o raiz de `\content`

# %%
# !pwd
# !cp /content/testes/* .
#!ls
# Out:
# /content

# %% [markdown]
# # Executando os testes
#
# * É preciso alterar o nome `tpplex.py` para o nome do arquivo da sua implementação do analisador léxico.

# %%
# !sh run-tests.sh lexeHigor.py
# Out:
# Testing with bubble_sort-2020-2.tpp
# Testing with bubble_sort_2.tpp
# Testing with bubble_sort.tpp
# Testing with Busca_Linear_1061992.tpp
# Testing with buscaLinear-2020-2.tpp
# Testing with comp.tpp
# Testing with fatorial-2020-2.tpp
# Testing with fatorial.tpp
# Testing with fat.tpp
# Testing with fibonacci-2020-2.tpp
# Testing with fibonacci.tpp
# Testing with hanoi-2020-2.tpp
# Testing with insertionSort-2020-2.tpp
# Testing with insertSort-2020-2.tpp
# Testing with maiorDoVetor.tpp
# Testing with multiplicavetor.tpp
# Testing with operacao_vetor-2020-2.tpp
# Testing with paraBinario-2020-2.tpp
# Testing with primo.tpp
# Testing with produtoEscalar.tpp
# Testing with prog_test.tpp
# Testing with sample.tpp
# Testing with selectionSort-2020-2.tpp
# Testing with selectionsort.tpp
# Testing with soma_maior_que_3.tpp
# Testing with somavet.tpp
# Testing with subtraiVetores.tpp
# Testing with teste-001.tpp
# Testing with teste-002.tpp
# Testing with teste-003.tpp
# Testing with verifica_valor_10.tpp
# Testing with verif_num_negativo.tpp
# -------------------------------------------------
# Relatório dos Testes:
# -------------------------------------------------
# 00. Teste bubble_sort-2020-2.tpp.diff        [OK]
# 00. Teste bubble_sort_2.tpp.diff             [OK]
# 00. Teste bubble_sort.tpp.diff               [OK]
# 00. Teste Busca_Linear_1061992.tpp.diff      [OK]
# 00. Teste buscaLinear-2020-2.tpp.diff        [OK]
# 00. Teste comp.tpp.diff                      [OK]
# 00. Teste fatorial-2020-2.tpp.diff           [OK]
# 00. Teste fatorial.tpp.diff                  [OK]
# 00. Teste fat.tpp.diff                       [OK]
# 00. Teste fibonacci-2020-2.tpp.diff          [OK]
# 00. Teste fibonacci.tpp.diff                 [OK]
# 00. Teste hanoi-2020-2.tpp.diff              [OK]
# 00. Teste insertionSort-2020-2.tpp.diff      [OK]
# 00. Teste insertSort-2020-2.tpp.diff         [OK]
# 00. Teste maiorDoVetor.tpp.diff              [OK]
# 00. Teste multiplicavetor.tpp.diff           [OK]
# 00. Teste operacao_vetor-2020-2.tpp.diff     [OK]
# 00. Teste paraBinario-2020-2.tpp.diff        [OK]
# 00. Teste primo.tpp.diff                     [OK]
# 00. Teste produtoEscalar.tpp.diff            [OK]
# 00. Teste prog_test.tpp.diff                 [OK]
# 00. Teste sample.tpp.diff                    [OK]
# 00. Teste selectionSort-2020-2.tpp.diff      [OK]
# 00. Teste selectionsort.tpp.diff             [OK]
# 00. Teste soma_maior_que_3.tpp.diff          [OK]
# 00. Teste somavet.tpp.diff                   [OK]
# 00. Teste subtraiVetores.tpp.diff            [OK]
# 00. Teste teste-001.tpp.diff                 [OK]
# 00. Teste teste-002.tpp.diff                 [OK]
# 00. Teste teste-003.tpp.diff                 [OK]
# 00. Teste verifica_valor_10.tpp.diff         [OK]
# 00. Teste verif_num_negativo.tpp.diff        [OK]
# -------------------------------------------------
# OK
# -------------------------------------------------

# %% [markdown]
# # Executando os testes e salvando o relatório em arquivo
#
# * Edite o nome do arquivo, coloque seu Nome e RA.

# %%
# !sh run-tests.sh lexeTST.py > relatorio-execucao-testes-Higor-1602870.txt
# !cat relatorio-execucao-testes-Higor-1602870.txt
# Out:
# Testing with bubble_sort-2020-2.tpp
# Testing with bubble_sort_2.tpp
# Testing with bubble_sort.tpp
# Testing with Busca_Linear_1061992.tpp
# Testing with buscaLinear-2020-2.tpp
# Testing with comp.tpp
# Testing with fatorial-2020-2.tpp
# Testing with fatorial.tpp
# Testing with fat.tpp
# Testing with fibonacci-2020-2.tpp
# Testing with fibonacci.tpp
# Testing with hanoi-2020-2.tpp
# Testing with insertionSort-2020-2.tpp
# Testing with insertSort-2020-2.tpp
# Testing with maiorDoVetor.tpp
# Testing with multiplicavetor.tpp
# Testing with operacao_vetor-2020-2.tpp
# Testing with paraBinario-2020-2.tpp
# Testing with primo.tpp
# Testing with produtoEscalar.tpp
# Testing with prog_test.tpp
# Testing with sample.tpp
# Testing with selectionSort-2020-2.tpp
# Testing with selectionsort.tpp
# Testing with soma_maior_que_3.tpp
# Testing with somavet.tpp
# Testing with subtraiVetores.tpp
# Testing with teste-001.tpp
# Testing with teste-002.tpp
# Testing with teste-003.tpp
# Testing with verifica_valor_10.tpp
# Testing with verif_num_negativo.tpp
# -------------------------------------------------
# Relatório dos Testes:
# -------------------------------------------------
# 00. Teste bubble_sort-2020-2.tpp.diff        [OK]
# 00. Teste bubble_sort_2.tpp.diff             [OK]
# 00. Teste bubble_sort.tpp.diff               [OK]
# 00. Teste Busca_Linear_1061992.tpp.diff      [OK]
# 00. Teste buscaLinear-2020-2.tpp.diff        [OK]
# 00. Teste comp.tpp.diff                      [OK]
# 00. Teste fatorial-2020-2.tpp.diff           [OK]
# 00. Teste fatorial.tpp.diff                  [OK]
# 00. Teste fat.tpp.diff                       [OK]
# 00. Teste fibonacci-2020-2.tpp.diff          [OK]
# 00. Teste fibonacci.tpp.diff                 [OK]
# 00. Teste hanoi-2020-2.tpp.diff              [OK]
# 00. Teste insertionSort-2020-2.tpp.diff      [OK]
# 00. Teste insertSort-2020-2.tpp.diff         [OK]
# 00. Teste maiorDoVetor.tpp.diff              [OK]
# 00. Teste multiplicavetor.tpp.diff           [OK]
# 00. Teste operacao_vetor-2020-2.tpp.diff     [OK]
# 00. Teste paraBinario-2020-2.tpp.diff        [OK]
# 00. Teste primo.tpp.diff                     [OK]
# 00. Teste produtoEscalar.tpp.diff            [OK]
# 00. Teste prog_test.tpp.diff                 [OK]
# 00. Teste sample.tpp.diff                    [OK]
# 00. Teste selectionSort-2020-2.tpp.diff      [OK]
# 00. Teste selectionsort.tpp.diff             [OK]
# 00. Teste soma_maior_que_3.tpp.diff          [OK]
# 00. Teste somavet.tpp.diff                   [OK]
# 00. Teste subtraiVetores.tpp.diff            [OK]
# 00. Teste teste-001.tpp.diff                 [OK]
# 00. Teste teste-002.tpp.diff                 [OK]
# 00. Teste teste-003.tpp.diff                 [OK]
# 00. Teste verifica_valor_10.tpp.diff         [OK]
# 00. Teste verif_num_negativo.tpp.diff        [OK]
# -------------------------------------------------
# OK
# -------------------------------------------------

# %% [markdown]
# # Fazendo Download do Arquivo de Relatório de Execução
#
# * Edite o nome do arquivo, coloque seu Nome e RA.

# %%
from google.colab import files
files.download('/content/relatorio-execucao-testes-Higor-1602870.txt')
